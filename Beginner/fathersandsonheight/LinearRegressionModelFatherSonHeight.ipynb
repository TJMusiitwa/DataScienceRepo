# %% [markdown]
# # Creating a Linear Regression Model to predict Son's Height from the Father

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv('fathersandsonheight/Pearson.txt', header=[0], delimiter="\t")

# %%
data.head()
# Out:
#    Father   Son
# 0    65.0  59.8
# 1    63.3  63.2
# 2    65.0  63.3
# 3    65.8  62.8
# 4    61.1  64.3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 2 columns):
# Father    1078 non-null float64
# Son       1078 non-null float64
# dtypes: float64(2)
# memory usage: 16.9 KB

# %%
data.describe()
# Out:
#             Father          Son
# count  1078.000000  1078.000000
# mean     67.686827    68.684230
# std       2.745827     2.816194
# min      59.000000    58.500000
# 25%      65.800000    66.900000
# 50%      67.800000    68.600000
# 75%      69.600000    70.500000
# max      75.400000    78.400000

# %%
data.corr()
# Out:
#           Father       Son
# Father  1.000000  0.501163
# Son     0.501163  1.000000

# %%
sns.heatmap(data=data, annot=True)

# %%
sns.pairplot(data=data)

# %%
#JointPlot
sns.jointplot(x='Father', y='Son', data=data, kind='hex')

# %%
sns.distplot(data['Father'])

# %%
sns.distplot(data['Son'])

# %%
plt.hist(x=data['Father'])
# Out:
# (array([  7.,  18.,  70., 140., 214., 260., 198., 107.,  55.,   9.]),
#  array([59.  , 60.64, 62.28, 63.92, 65.56, 67.2 , 68.84, 70.48, 72.12,
#         73.76, 75.4 ]),
#  <a list of 10 Patch objects>)

# %%
sns.lmplot(x='Father', y='Son', data=data)

# %% [markdown]
# # Building the Linear Model

# %%
X = data['Father']
y = data['Son']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
import numpy as np

# %%
trainArray = np.asfarray(X_train)

# %%
trainArray.reshape(-1,1)
# Out:
# array([[68.7],
#        [70.2],
#        [70.2],
#        [65.7],
#        [65.6],
#        [70.6],
#        [64.9],
#        [70. ],
#        [67.3],
#        [69.4],
#        [69.2],
#        [66.7],
#        [66. ],
#        [65.9],
#        [62.8],
#        [63.7],
#        [62.5],
#        [65.6],
#        [68.5],
#        [71.5],
#        [69.3],
#        [67.8],
#        [64.5],
#        [63.9],
#        [68.3],
#        [64.6],
#        [69.1],
#        [69.9],
#        [69.3],
#        [75.4],
#        [64.3],
#        [67.1],
#        [65.1],
#        [66. ],
#        [67.3],
#        [68.6],
#        [68.4],
#        [64.6],
#        [74.7],
#        [70.9],
#        [70.5],
#        [71.3],
#        [68.4],
#        [63.2],
#        [67.2],
#        [66. ],
#        [69.6],
#        [68.6],
#        [65.8],
#        [64.4],
#        [69. ],
#        [69.3],
#        [66.9],
#        [68.8],
#        [67.7],
#        [69.6],
#        [68.9],
#        [70.4],
# ...

# %%
yTrainArray = np.asfarray(y_train)
yTrainArray.reshape(-1,1)
# Out:
# array([[69.4],
#        [67.7],
#        [67.6],
#        [67.7],
#        [66.8],
#        [71.6],
#        [64.4],
#        [71.2],
#        [67.5],
#        [70.2],
#        [72.4],
#        [70.4],
#        [66.3],
#        [66.9],
#        [68. ],
#        [69.6],
#        [66.6],
#        [70.5],
#        [68.9],
#        [68.7],
#        [66.6],
#        [71.8],
#        [62.5],
#        [65.9],
#        [67. ],
#        [67.5],
#        [68.2],
#        [67.8],
#        [68.7],
#        [70.1],
#        [65.1],
#        [66.4],
#        [68.1],
#        [70. ],
#        [67.9],
#        [68.7],
#        [67.9],
#        [69.5],
#        [74.3],
#        [70.9],
#        [70.3],
#        [68.3],
#        [70.9],
#        [68.1],
#        [68.6],
#        [66.4],
#        [69.3],
#        [67. ],
#        [69. ],
#        [71.1],
#        [71. ],
#        [68.2],
#        [67.7],
#        [72.9],
#        [68.1],
#        [68.1],
#        [68.6],
#        [69.3],
# ...
