# %% [markdown]
# # The BigMart Sales Challenge

# %%
# Import required packages
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(rc={'figure.figsize':(12,9)})

# %%
train = pd.read_csv('bigmart-sales-data/Train.csv', sep=',')
test = pd.read_csv('bigmart-sales-data/Test.csv', sep=',')

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Fill the missing values with the average value.
train.fillna(method=)

# %%
train.sample(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5247           DRG37        16.20          Low Fat         0.019362
# 7453           NCY29        13.65          Low Fat         0.077220
# 2249           DRE15        13.35          Low Fat         0.000000
# 3715           FDO57        20.75          Low Fat         0.108879
# 120            NCF19        13.00          Low Fat         0.035307
# 3102           DRL35        15.70          Low Fat         0.030751
# 4844           FDC09        15.50          Regular         0.044024
# 1417           FDV39        11.30          Low Fat         0.007279
# 3330           FDP20        19.85          Low Fat         0.045762
# 2261           FDP37        15.60          Low Fat         0.143396
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 5247            Soft Drinks  154.6972            OUT013
# 7453     Health and Hygiene   56.4930            OUT035
# 2249                  Dairy   77.6012            OUT046
# 3715            Snack Foods  161.5578            OUT049
# 120               Household   47.5034            OUT017
# 3102            Hard Drinks   42.5770            OUT049
# 4844  Fruits and Vegetables  102.0332            OUT010
# 1417                   Meat  196.7426            OUT035
# 3330  Fruits and Vegetables  125.6020            OUT045
# 2261              Breakfast  128.0994            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5247                       1987        High               Tier 3
# 7453                       2004       Small               Tier 2
# 2249                       1997       Small               Tier 1
# 3715                       1999      Medium               Tier 1
# 120                        2007         NaN               Tier 2
# 3102                       1999      Medium               Tier 1
# 4844                       1998         NaN               Tier 3
# 1417                       2004       Small               Tier 2
# 3330                       2002         NaN               Tier 2
# 2261                       2002         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 5247  Supermarket Type1          1713.7692
# 7453  Supermarket Type1           509.3370
# 2249  Supermarket Type1           986.7156
# 3715  Supermarket Type1           320.9156
# 120   Supermarket Type1           680.4476
# 3102  Supermarket Type1           952.0940
# 4844      Grocery Store           102.5332
# 1417  Supermarket Type1          2768.3964
# 3330  Supermarket Type1           632.5100
# 2261  Supermarket Type1          2184.4898

# %% [markdown]
# # Data Visualisation

# %%
sns.heatmap(train.corr().round(3), annot=True)

# %%
sns.countplot(x='Outlet_Location_Type', data=train)

# %%
sns.countplot(x='Outlet_Type', data=train)

# %%
sns.countplot(x='Outlet_Size', data=train)

# %%
sns.countplot(x='Item_Type', data=train)

# %%
sns.countplot(x='Item_Fat_Content', data=train)

# %%
sns.distplot(train['Outlet_Establishment_Year'])

# %%
sns.distplot(train['Item_MRP'], bins=10)

# %%
sns.boxplot(x='Item_Type', y='Item_MRP', data = train, hue='Item_Fat_Content', palette='seismic')

# %%
train['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)
