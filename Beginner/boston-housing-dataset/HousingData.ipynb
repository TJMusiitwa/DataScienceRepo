# %% [markdown]
# # Housing Data

# %%
# Import required packages
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.set(rc={'figure.figsize':(12,9)})

# %%
housing = pd.read_csv('boston-housing-dataset/HousingData.csv', sep=',')
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       486 non-null float64
# ZN         486 non-null float64
# INDUS      486 non-null float64
# CHAS       486 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        486 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      486 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560262   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
housing.fillna(value=0, inplace=True, axis=1)

# %%
housing.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
housing.sample(5)
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 376  15.28800  0.0  18.10   0.0  0.671  6.649  93.3  1.3449   24  666
# 41    0.12744  0.0   6.91   0.0  0.448  6.770   2.9  5.7209    3  233
# 17    0.78420  0.0   8.14   0.0  0.538  5.990  81.7  4.2579    4  307
# 121   0.07165  0.0  25.65   0.0  0.581  6.004  84.1  2.1974    2  188
# 126   0.38735  0.0  25.65   0.0  0.581  5.613   0.0  1.7572    2  188
#
#      PTRATIO       B  LSTAT  MEDV
# 376     20.2  363.02   0.00  13.9
# 41      17.9  385.41   4.84  26.6
# 17      21.0  386.75  14.67  17.5
# 121     19.1  377.67  14.27  20.3
# 126     19.1  359.29  27.26  15.7

# %%
sns.distplot(housing['MEDV'])

# %%
sns.heatmap(data=housing.corr().round(2), annot=True)

# %%
#sns.pairplot(housing)

# %%
X = housing.drop('MEDV', axis=1)
y = housing['MEDV']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=100)

# %%
#Create the linear model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lr.intercept_)
# Out:
# 29.90685435925523

# %%
predictions = lr.predict(X_test)

# %%
#Residuals Plot
sns.distplot(y_test - predictions)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 3.50141829869423

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 31.285403350384506

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 5.59333561932274

# %%
metrics.r2_score(y_test,predictions)
# Out:
# 0.691114989149088

# %% [markdown]
# Using Feature-selected data points for the model

# %%
X2 = housing[['RM', 'LSTAT', 'PTRATIO']]
y2 = housing['MEDV']

# %%
sns.heatmap(X2.corr().round(2), annot=True)

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.30, random_state=100)

# %%
lr2 = LinearRegression()

# %%
lr2.fit(X2_train,y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lr2.intercept_)
# Out:
# 17.514635057093084

# %%
predictions2 = lr2.predict(X2_test)

# %%
#Residuals Plot
sns.distplot(y2_test - predictions2)

# %%
metrics.mean_absolute_error(y2_test, predictions2)
# Out:
# 3.9314561706246893

# %%
metrics.mean_squared_error(y2_test, predictions2)
# Out:
# 37.396393103252386

# %%
np.sqrt(metrics.mean_squared_error(y2_test, predictions2))
# Out:
# 6.115259038115425

# %%
metrics.r2_score(y2_test,predictions2)
# Out:
# 0.6307803623269854

# %%
plt.scatter(y_test,predictions)
plt.xlabel('MEDV')
plt.ylabel('Predicted MEDV')
# Out:
# Text(0, 0.5, 'Predicted MEDV')

# %%
sns.scatterplot(y2_test, predictions2)
