# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
calls_911 = pd.read_csv('https://www.kaggle.com/mchirico/montcoalert#911.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-a1d15d042dc3> in <module>()
# ----> 1 calls_911 = pd.read_csv('https://www.kaggle.com/mchirico/montcoalert#911.csv')
#
# ...
