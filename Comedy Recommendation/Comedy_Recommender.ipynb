# %% [markdown]
# COMEDY SHOWS RECOMMENDER SYSTEM

# %%
# Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Import the training file for the problem

# %%
df = pd.read_csv('C:/Users/Gloria/Desktop/Data Science/Comedy Recommendation/train/train.csv')

# %%
#Inspect the head of the data
df.head()
# Out:
#   Viewers_ID         Joke_identifier                Response_ID  Rating
# 0         A1  Klint De Drunk Enugu 1  A1_Klint De Drunk Enugu 1    0.11
# 1         A1  Klint De Drunk Enugu 2  A1_Klint De Drunk Enugu 2   -4.64
# 2         A1     Klint De Drunk PH 1     A1_Klint De Drunk PH 1   -3.39
# 3         A1     Klint De Drunk PH 2     A1_Klint De Drunk PH 2    0.44
# 4         A1  Klint De Drunk Lagos 1  A1_Klint De Drunk Lagos 1   -4.83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612702 entries, 0 to 612701
# Data columns (total 4 columns):
# Viewers_ID         612702 non-null object
# Joke_identifier    612702 non-null object
# Response_ID        612702 non-null object
# Rating             612702 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 18.7+ MB

# %%
#Describe the data to us
df.describe()
# Out:
#               Rating
# count  612702.000000
# mean        0.647024
# std         2.667301
# min        -5.000000
# 25%        -1.300000
# 50%         0.950000
# 75%         2.690000
# max         5.000000

# %%
#Look for any null values
df.isnull().sum()
# Out:
# Viewers_ID         0
# Joke_identifier    0
# Response_ID        0
# Rating             0
# dtype: int64

# %%
df.groupby('Joke_identifier')['Rating'].count().sort_values(ascending=False).head(15)
# Out:
# Joke_identifier
# Klint De Drunk PH 2        26311
# Klint De Drunk Enugu 2     26286
# Klint De Drunk PH 1        26254
# Klint De Drunk Enugu 3     26234
# Klint De Drunk Lagos 1     25864
# Klint De Drunk Lagos 2     24788
# Klint De Drunk Lagos 3     23358
# Klint De Drunk Warri 1     21278
# AliBaba PH 2               13149
# AY Warri 1                 12501
# AliBaba PH 5               12310
# Akpororo Lagos 1            9965
# BasketMouth Lagos 1         9853
# Akpororo Warri 2            9583
# AY Abuja 1                  9538
# Name: Rating, dtype: int64

# %%
df.groupby('Joke_identifier')['Rating'].mean().sort_values(ascending=False).head(15)
# Out:
# Joke_identifier
# Funny Bone Abuja 3      2.776667
# Okey Bakassi Lagos 1    2.637500
# Gordons Lagos 2         2.022706
# Okey Bakassi Lagos 3    1.980000
# AY Warri 1              1.928956
# I Go Dye Benin 1        1.856578
# Gordons Lagos 1         1.828863
# Akpororo Lagos 1        1.808704
# AliBaba PH 5            1.796185
# AliBaba PH 2            1.761211
# Akpororo Warri 1        1.739898
# Bovi Lagos 4            1.715548
# Gordons Lagos 3         1.666066
# AY Abuja 1              1.644047
# Akpororo Warri 2        1.641153
# Name: Rating, dtype: float64

# %% [markdown]
# Data Visualisation

# %%
df['Rating'].hist()
